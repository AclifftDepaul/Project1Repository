# %%
import os

# Module for reading CSV files
import csv
import pandas as pd


file_one = "../Resources/Adult_Tobacco_Consumption_In_The_U.S.__2000-Present_20231019.csv"
file_two = "../Resources/data-table.csv"


DrugFullDF = pd.read_csv(file_one, delimiter = ',' )
CancerRate = pd.read_csv(file_two, delimiter = ',' )

DrugFullDF = DrugFullDF.dropna()
CancerRate = CancerRate.dropna()

CancerRate['deaths'] = [str(x).strip(',')[-3] for x in CancerRate.iloc[:,3]]

CancerRate["deaths"] = CancerRate["deaths"].astype('int64')

CancerRate
# Out:
#      YEAR STATE   RATE  DEATHS  \
# 0    2021    AL  160.2   10429
# 1    2021    AK  156.0    1093
# 2    2021    AZ  134.7   12813
# 3    2021    AR  168.2    6516
# 4    2021    CA  132.4   59503
# ..    ...   ...    ...     ...
# 445  2005    VA  190.0  13,877
# 446  2005    WA  181.0  11,048
# 447  2005    WV  207.4   4,617
# 448  2005    WI  182.8  10,943
# 449  2005    WY  169.2     886
#
#                                                    URL  deaths
# 0                /nchs/pressroom/states/alabama/al.htm       4
# 1                 /nchs/pressroom/states/alaska/ak.htm       0
# 2                /nchs/pressroom/states/arizona/az.htm       8
# 3               /nchs/pressroom/states/arkansas/ar.htm       5
# 4             /nchs/pressroom/states/california/ca.htm       5
# ..                                                 ...     ...
# 445       /nchs/pressroom/states/virginia/virginia.htm       8
# 446   /nchs/pressroom/states/washington/washington.htm       0
# ...

# %%
DrugNonCombustibleDF = DrugFullDF.loc[DrugFullDF['Topic'] == 'Noncombustible Tobacco']
DrugNonCombustibleDF.head()
# Out:
#     Year LocationAbbrev LocationDesc  Population                   Topic  \
# 0   2000             US     National   209786736  Noncombustible Tobacco
# 11  2000             US     National   209786736  Noncombustible Tobacco
# 15  2001             US     National   212345162  Noncombustible Tobacco
# 16  2001             US     National   212345162  Noncombustible Tobacco
# 31  2002             US     National   214754648  Noncombustible Tobacco
#
#               Measure       Submeasure Data Value Unit  Domestic  Imports  \
# 0   Smokeless Tobacco  Chewing Tobacco          Pounds  45502156    91965
# 11  Smokeless Tobacco            Snuff          Pounds  66134630    17729
# 15  Smokeless Tobacco  Chewing Tobacco          Pounds  49397524   102162
# 16  Smokeless Tobacco            Snuff          Pounds  69804806    11675
# 31  Smokeless Tobacco  Chewing Tobacco          Pounds  47095214   215769
#
#        Total  Domestic Per Capita  Imports Per Capita  Total Per Capita
# ...

# %%
TotalDrugNonCombustibleDF = DrugNonCombustibleDF.groupby(['Year']).sum()
TotalDrugNonCombustibleDF.head()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_36628\798319667.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   TotalDrugNonCombustibleDF = DrugNonCombustibleDF.groupby(['Year']).sum()
#       Population   Domestic  Imports      Total  Domestic Per Capita  \
# Year
# 2000   419573472  111636786   109694  111746480                0.532
# 2001   424690324  119202330   113837  119316167                0.562
# 2002   429509296  118338146   225596  118563742                0.551
# 2003   434136202  120606782   182768  120789550                0.555
# 2004   439105858  120923633   225727  121149360                0.551
#
#       Imports Per Capita  Total Per Capita
# Year
# 2000               0.000             0.532
# 2001               0.000             0.562
# ...

# %%
DrugFullDFYear = DrugFullDF.groupby(['Year']).sum()
DrugFullDFYear = DrugFullDFYear.drop("Population", axis='columns')
DrugFullDFYear
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_36628\981977864.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   DrugFullDFYear = DrugFullDF.groupby(['Year']).sum()
#           Domestic      Imports         Total  Domestic Per Capita  \
# Year
# 2000  888358463835  28395244568  916753708403             4236.532
# 2001  861457029370  34051515644  895508545015             4055.562
# 2002  830187294069  46532488445  876719782514             3865.551
# 2003  796500900664  51118156633  847619057296             3669.555
# 2004  795675783622  50089679632  845765463254             3623.551
# 2005  779331592972  43295937178  822627530150             3510.536
# 2006  783973524627  39328490610  823302015237             3491.558
# 2007  755488146048  35353467849  790841613896             3324.542
# ...

# %%
CancerRate = CancerRate.groupby(['YEAR']).sum()
CancerRate
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_36628\1773116029.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   CancerRate = CancerRate.groupby(['YEAR']).sum()
#         RATE
# YEAR
# 2005  9290.5
# 2014  8175.8
# 2015  8060.0
# 2016  7905.6
# 2017  7752.1
# 2018  7575.7
# 2019  7454.8
# 2020  7356.4
# 2021  7515.0
