# %%
import os

# Module for reading CSV files
import csv
import pandas as pd


file_one = "Resources/cancerdrugsdb.txt"

DrugFullDF = pd.read_csv(file_one, delimiter = '\t' )

DrugFullDF = DrugFullDF.drop(['Unnamed: 14','Other'], axis=1)
DrugFullDF = DrugFullDF.dropna()

DrugFullDF.head()
# Out:
#          Product EMA FDA EN WHO    Year Generic  \
# 0    Abemaciclib   Y   Y  N   N  2017.0       N
# 1    Abiraterone   Y   Y  N   Y  2011.0       Y
# 2  Acalabrutinib   Y   Y  N   N  2017.0       N
# 5       Afatinib   Y   Y  N   Y  2013.0       N
# 6    Aflibercept   Y   Y  N   N  2011.0       N
#
#                                          DrugBank ID               ATC  \
# 0  <a href="https://go.drugbank.com/drugs/DB12001...           L01EF03
# 1  <a href="https://go.drugbank.com/drugs/DB05812...           L02BX03
# 2  <a href="https://go.drugbank.com/drugs/DB11703...           L01EL02
# 5  <a href="https://go.drugbank.com/drugs/DB08916...           L01EB03
# 6  <a href="https://go.drugbank.com/drugs/DB08885...  S01LA05; L01XX44
#
#                                               ChEMBL  \
# 0  <a href="https://www.ebi.ac.uk/chembl/compound...
# 1  <a href="https://www.ebi.ac.uk/chembl/compound...
# 2  <a href="https://www.ebi.ac.uk/chembl/compound...
# 5  <a href="https://www.ebi.ac.uk/chembl/compound...
# 6  <a href="https://www.ebi.ac.uk/chembl/compound...
#
#                                          Indications  \
# 0   Advanced Breast Cancer; Metastatic Breast Cancer
# 1    Metastatic Castration Resistant Prostate Cancer
# 2  Chronic Lymphocytic Leukaemia (CLL); Mantle Ce...
# 5  Metastatic Non-Small Cell Lung Cancer; Refract...
# 6                Metastatic Colorectal Cancer (MCRC)
#
#                                              Targets Last Update
# 0  CDK6; CDK4; CCND1; CCND3; CDKN2A; NRAS; CCND2;...  2022-02-01
# 1                         CYP17A1; DSE; TSPYL1; PTEN  2023-08-01
# 2                                                BTK  2022-06-22
# 5  EGFR; ERBB2; ERBB4; KRAS; EML4; MET; BRAF; NRG...  2022-02-01
# 6                     VEGFA; VEGFB; PGF; PIGF; VEGFC  2020-09-17
