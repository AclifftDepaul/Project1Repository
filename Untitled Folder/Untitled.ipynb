# %%
import os

# Module for reading CSV files
import csv
import pandas as pd


file_one = "../Resources/02 total-cancer-deaths-by-type.csv"
file_two = "../Resources/global air pollution dataset.csv"

PollutionFullDF = pd.read_csv(file_two, delimiter = ",")
CancerAreaDF = pd.read_csv(file_one, delimiter = ",")

PollutionFullDF = PollutionFullDF.dropna()
CancerAreaDF = CancerAreaDF.dropna()

PollutionFullDF

# Create a new DataFrame with only the desired columns
columns_to_keep = ['Country', 'AQI Value', 'AQI Category']

# Create a new DataFrame with only the desired columns
filtered_df = PollutionFullDF[columns_to_keep]
filtered_df
# Out:
#                         Country  AQI Value AQI Category
# 0            Russian Federation         51     Moderate
# 1                        Brazil         41         Good
# 2                         Italy         66     Moderate
# 3                        Poland         34         Good
# 4                        France         22         Good
# ...                         ...        ...          ...
# 23458                     India        184    Unhealthy
# 23459                    France         50         Good
# 23460                     India         50         Good
# 23461  United States of America         71     Moderate
# 23462                  Malaysia         70     Moderate
#
# [23035 rows x 3 columns]

# %%
YearCancerAreaDF = CancerAreaDF.loc[(CancerAreaDF["Year"] == 2019)]
YearCancerAreaDF
# Out:
#               Entity      Code  Year  \
# 29       Afghanistan       AFG  2019
# 89           Albania       ALB  2019
# 119          Algeria       DZA  2019
# 149   American Samoa       ASM  2019
# 179          Andorra       AND  2019
# ...              ...       ...   ...
# 6539         Vietnam       VNM  2019
# 6629           World  OWID_WRL  2019
# 6779           Yemen       YEM  2019
# 6809          Zambia       ZMB  2019
# 6839        Zimbabwe       ZWE  2019
#
#       Deaths - Liver cancer - Sex: Both - Age: All Ages (Number)  \
# 29                                                 1376
# 89                                                  294
# 119                                                 688
# 149                                                   3
# 179                                                  13
# ...                                                 ...
# 6539                                               2387
# ...

# %%
import matplotlib.pyplot as plt

# Step 1: Aggregate the data
# Average AQI per country
average_aqi = df_aqi.groupby('Country')['AQI Value'].mean().reset_index()

# Total cancer deaths per country
df_cancer['Total Cancer Deaths'] = df_cancer.iloc[:, 3:].sum(axis=1)  # sum across all cancer types
total_cancer_deaths = df_cancer.groupby('Entity')['Total Cancer Deaths'].sum().reset_index()

# Step 2: Merge the two datasets on the country columns
merged_data = pd.merge(average_aqi, total_cancer_deaths, left_on='Country', right_on='Entity')

# Step 3: Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(merged_data['AQI Value'], merged_data['Total Cancer Deaths'], color='b')
plt.title('Correlation between Air Quality Index and Total Cancer Deaths by Country')
plt.xlabel('Average AQI Value')
plt.ylabel('Total Cancer Deaths')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       1 import matplotlib.pyplot as plt
#       3 # Assuming you've loaded your data into pandas DataFrames: df_aqi and df_cancer
#       4
#       5 # Step 1: Aggregate the data
#       6 # Average AQI per country
# ----> 7 average_aqi = df_aqi.groupby('Country')['AQI Value'].mean().reset_index()
#       9 # Total cancer deaths per country
#      10 df_cancer['Total Cancer Deaths'] = df_cancer.iloc[:, 3:].sum(axis=1)  # sum across all cancer types
#
# NameError: name 'df_aqi' is not defined
