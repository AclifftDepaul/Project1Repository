# %%
import os

# Module for reading CSV files
import csv
import pandas as pd
import matplotlib.pyplot as plt



file_one = "../Resources/data-table.csv"
file_two = "../Resources/Obesity-prevalence-by-state-2021.csv"

ObesityFullDF = pd.read_csv(file_two, delimiter = ",")


CancerAreaDF = pd.read_csv(file_one, delimiter = ",")
ObesityFullDF = ObesityFullDF.dropna()
CancerAreaDF = CancerAreaDF.dropna()
ObesityFullDF
# Out:
#                    State Prevalence        95% CI
# 0                Alabama       39.9  (37.9, 41.8)
# 1                 Alaska       33.5  (31.5, 35.5)
# 2                Arizona       31.3  (30.0, 32.6)
# 3               Arkansas       38.7  (36.6, 40.8)
# 4             California       27.6  (26.1, 29.1)
# 5               Colorado       25.1  (24.1, 26.2)
# 6            Connecticut       30.4  (28.9, 31.9)
# 7               Delaware       33.9  (31.8, 36.1)
# 8   District of Columbia       24.7  (22.6, 26.9)
# 9                Florida    No data       No data
# 10               Georgia       33.9  (32.2, 35.6)
# 11                  Guam       33.5  (29.2, 38.1)
# 12                Hawaii       25.0  (23.6, 26.4)
# 13                 Idaho       31.6  (30.2, 33.0)
# 14              Illinois       34.2  (31.8, 36.6)
# 15               Indiana       36.3  (35.1, 37.5)
# 16                  Iowa       36.4  (35.1, 37.7)
# 17                Kansas       36.0  (35.1, 37.0)
# 18              Kentucky       40.3  (38.5, 42.2)
# 19             Louisiana       38.6  (36.7, 40.6)
# 20                 Maine       31.9  (30.6, 33.2)
# 21              Maryland       34.3  (33.2, 35.5)
# 22         Massachusetts       27.4  (25.9, 28.8)
# 23              Michigan       34.4  (33.1, 35.7)
# 24             Minnesota       32.4  (31.5, 33.3)
# 25           Mississippi       39.1  (37.1, 41.1)
# 26              Missouri       37.3  (35.9, 38.7)
# 27               Montana       31.8  (30.3, 33.3)
# 28              Nebraska       35.9  (34.8, 37.1)
# 29                Nevada       31.3  (28.7, 34.1)
# 30         New Hampshire       30.6  (29.0, 32.3)
# 31            New Jersey       28.2  (26.8, 29.6)
# 32            New Mexico       34.6  (32.9, 36.3)
# 33              New York       29.1  (28.3, 30.0)
# 34        North Carolina       36.0  (34.2, 37.9)
# 35          North Dakota       35.2  (33.6, 36.9)
# 36                  Ohio       37.8  (36.6, 39.0)
# 37              Oklahoma       39.4  (37.7, 41.2)
# 38                Oregon       30.4  (28.9, 31.9)
# 39          Pennsylvania       33.3  (31.7, 34.9)
# 40           Puerto Rico       36.0  (33.9, 38.1)
# 41          Rhode Island       30.1  (28.4, 31.8)
# 42        South Carolina       36.1  (34.6, 37.5)
# 43          South Dakota       38.4  (35.6, 41.4)
# 44             Tennessee       35.0  (33.1, 36.8)
# 45                 Texas       36.1  (34.4, 37.8)
# 46                  Utah       30.9  (29.8, 32.1)
# 47               Vermont       29.0  (27.4, 30.7)
# 48        Virgin Islands       35.6  (28.7, 43.2)
# 49              Virginia       34.2  (32.9, 35.6)
# 50            Washington       28.8  (27.7, 29.9)
# 51         West Virginia       40.6  (39.1, 42.1)
# 52             Wisconsin       33.9  (32.1, 35.7)
# 53               Wyoming       32.0  (29.9, 34.1)

# %%
YearCancerAreaDF = CancerAreaDF.loc[(CancerAreaDF["YEAR"] == 2021)]
YearCancerAreaDF

YearCancerAreaDF['DEATHS'] = YearCancerAreaDF['DEATHS'].astype(int)
# Out:
# /var/folders/kc/r9q5_v3x3vx9sh_1q1hvz_380000gn/T/ipykernel_951/3819968743.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   YearCancerAreaDF['DEATHS'] = YearCancerAreaDF['DEATHS'].astype(int)

# %%
state_mapping = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming'
}

YearCancerAreaDF['STATE'] = YearCancerAreaDF['STATE'].map(state_mapping)
# Out:
# /var/folders/kc/r9q5_v3x3vx9sh_1q1hvz_380000gn/T/ipykernel_22882/3752258383.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   YearCancerAreaDF['STATE'] = YearCancerAreaDF['STATE'].map(state_mapping)

# %%
obesity_cancer_df = pd.merge(YearCancerAreaDF, ObesityFullDF, left_on='STATE', right_on='State', how='inner', suffixes=('', '_drop'))
obesity_cancer_df = obesity_cancer_df.drop(columns=['State'])
obesity_cancer_df = obesity_cancer_df[obesity_cancer_df['Prevalence'] != 'No data']

# Create the scatter plot


obesity_cancer_df
# Out:
#     YEAR           STATE   RATE DEATHS  \
# 0   2021         Alabama  160.2  10429
# 1   2021          Alaska  156.0   1093
# 2   2021         Arizona  134.7  12813
# 3   2021        Arkansas  168.2   6516
# 4   2021      California  132.4  59503
# 5   2021        Colorado  126.5   8058
# 6   2021     Connecticut  133.5   6526
# 7   2021        Delaware  153.2   2178
# 9   2021         Georgia  151.5  18136
# 10  2021          Hawaii  125.4   2562
# 11  2021           Idaho  140.4   3130
# 12  2021        Illinois  150.0  23609
# 13  2021         Indiana  169.7  13983
# 14  2021            Iowa  150.9   6258
# 15  2021          Kansas  150.8   5455
# 16  2021        Kentucky  181.1  10250
# 17  2021       Louisiana  163.9   9246
# 18  2021           Maine  161.3   3385
# 19  2021        Maryland  139.2  10545
# 20  2021   Massachusetts  137.4  12461
# 21  2021        Michigan  160.1  21211
# 22  2021       Minnesota  143.2  10178
# 23  2021     Mississippi  181.8   6617
# 24  2021        Missouri  164.2  13153
# 25  2021         Montana  142.2   2157
# 26  2021        Nebraska  150.9   3578
# 27  2021          Nevada  143.2   5318
# 28  2021   New Hampshire  145.7   2831
# 29  2021      New Jersey  130.6  15481
# 30  2021      New Mexico  137.3   3822
# 31  2021        New York  125.3  32601
# 32  2021  North Carolina  153.6  20229
# 33  2021    North Dakota  137.8   1278
# 34  2021            Ohio  163.0  25077
# 35  2021        Oklahoma  175.1   8368
# 36  2021          Oregon  155.2   8596
# 37  2021    Pennsylvania  152.9  27664
# 38  2021    Rhode Island  142.0   2115
# 39  2021  South Carolina  155.2  10593
# 40  2021    South Dakota  154.8   1739
# 41  2021       Tennessee  166.3  14481
# 42  2021           Texas  143.3  42552
# 43  2021            Utah  121.0   3492
# 44  2021         Vermont  154.0   1446
# 45  2021        Virginia  150.5  15724
# 46  2021      Washington  149.3  13547
# 47  2021   West Virginia  184.7   4820
# 48  2021       Wisconsin  147.2  11336
# 49  2021         Wyoming  156.7   1151
#
#                                             URL Prevalence        95% CI
# 0         /nchs/pressroom/states/alabama/al.htm       39.9  (37.9, 41.8)
# 1          /nchs/pressroom/states/alaska/ak.htm       33.5  (31.5, 35.5)
# 2         /nchs/pressroom/states/arizona/az.htm       31.3  (30.0, 32.6)
# 3        /nchs/pressroom/states/arkansas/ar.htm       38.7  (36.6, 40.8)
# 4      /nchs/pressroom/states/california/ca.htm       27.6  (26.1, 29.1)
# 5        /nchs/pressroom/states/colorado/co.htm       25.1  (24.1, 26.2)
# 6     /nchs/pressroom/states/connecticut/ct.htm       30.4  (28.9, 31.9)
# 7        /nchs/pressroom/states/delaware/de.htm       33.9  (31.8, 36.1)
# 9         /nchs/pressroom/states/georgia/ga.htm       33.9  (32.2, 35.6)
# 10         /nchs/pressroom/states/hawaii/hi.htm       25.0  (23.6, 26.4)
# 11          /nchs/pressroom/states/idaho/id.htm       31.6  (30.2, 33.0)
# 12       /nchs/pressroom/states/illinois/il.htm       34.2  (31.8, 36.6)
# 13        /nchs/pressroom/states/indiana/in.htm       36.3  (35.1, 37.5)
# 14           /nchs/pressroom/states/iowa/ia.htm       36.4  (35.1, 37.7)
# 15         /nchs/pressroom/states/kansas/ks.htm       36.0  (35.1, 37.0)
# 16       /nchs/pressroom/states/kentucky/ky.htm       40.3  (38.5, 42.2)
# 17      /nchs/pressroom/states/louisiana/la.htm       38.6  (36.7, 40.6)
# 18          /nchs/pressroom/states/maine/me.htm       31.9  (30.6, 33.2)
# 19       /nchs/pressroom/states/maryland/md.htm       34.3  (33.2, 35.5)
# 20  /nchs/pressroom/states/massachusetts/ma.htm       27.4  (25.9, 28.8)
# 21       /nchs/pressroom/states/michigan/mi.htm       34.4  (33.1, 35.7)
# 22      /nchs/pressroom/states/minnesota/mn.htm       32.4  (31.5, 33.3)
# 23    /nchs/pressroom/states/mississippi/ms.htm       39.1  (37.1, 41.1)
# 24       /nchs/pressroom/states/missouri/mo.htm       37.3  (35.9, 38.7)
# 25        /nchs/pressroom/states/montana/mt.htm       31.8  (30.3, 33.3)
# 26       /nchs/pressroom/states/nebraska/ne.htm       35.9  (34.8, 37.1)
# 27         /nchs/pressroom/states/nevada/nv.htm       31.3  (28.7, 34.1)
# 28   /nchs/pressroom/states/newhampshire/nh.htm       30.6  (29.0, 32.3)
# 29      /nchs/pressroom/states/newjersey/nj.htm       28.2  (26.8, 29.6)
# 30      /nchs/pressroom/states/newmexico/nm.htm       34.6  (32.9, 36.3)
# 31        /nchs/pressroom/states/newyork/ny.htm       29.1  (28.3, 30.0)
# 32  /nchs/pressroom/states/northcarolina/nc.htm       36.0  (34.2, 37.9)
# 33    /nchs/pressroom/states/northdakota/nd.htm       35.2  (33.6, 36.9)
# 34           /nchs/pressroom/states/ohio/oh.htm       37.8  (36.6, 39.0)
# 35       /nchs/pressroom/states/oklahoma/ok.htm       39.4  (37.7, 41.2)
# 36         /nchs/pressroom/states/oregon/or.htm       30.4  (28.9, 31.9)
# 37   /nchs/pressroom/states/pennsylvania/pa.htm       33.3  (31.7, 34.9)
# 38    /nchs/pressroom/states/rhodeisland/ri.htm       30.1  (28.4, 31.8)
# 39  /nchs/pressroom/states/southcarolina/sc.htm       36.1  (34.6, 37.5)
# 40    /nchs/pressroom/states/southdakota/sd.htm       38.4  (35.6, 41.4)
# 41      /nchs/pressroom/states/tennessee/tn.htm       35.0  (33.1, 36.8)
# 42          /nchs/pressroom/states/texas/tx.htm       36.1  (34.4, 37.8)
# 43           /nchs/pressroom/states/utah/ut.htm       30.9  (29.8, 32.1)
# 44        /nchs/pressroom/states/vermont/vt.htm       29.0  (27.4, 30.7)
# 45       /nchs/pressroom/states/virginia/va.htm       34.2  (32.9, 35.6)
# 46     /nchs/pressroom/states/washington/wa.htm       28.8  (27.7, 29.9)
# 47   /nchs/pressroom/states/westvirginia/wv.htm       40.6  (39.1, 42.1)
# 48      /nchs/pressroom/states/wisconsin/wi.htm       33.9  (32.1, 35.7)
# 49        /nchs/pressroom/states/wyoming/wy.htm       32.0  (29.9, 34.1)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have the 'ObesityFullDF' DataFrame already loaded

# Create a bar graph for obesity prevalence by state
plt.figure(figsize=(12, 10))
plt.bar(ObesityFullDF['State'], ObesityFullDF['Prevalence'], color='skyblue')
plt.title('Obesity Prevalence by State (2021)')
plt.xlabel('State')
plt.ylabel('Prevalence (%)')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Sort the DataFrame by RATE (cancer rate) in ascending order for a clearer bar chart
obesity_cancer_df = obesity_cancer_df.sort_values(by='RATE', ascending=False)

# Create a bar chart
plt.figure(figsize=(12, 8))
plt.barh(obesity_cancer_df['STATE'], obesity_cancer_df['RATE'], color='skyblue')
plt.title('Cancer Rate by State in 2021')
plt.xlabel('Cancer Rate')
plt.ylabel('State')
plt.gca().invert_yaxis()  # Reverse the order to have the highest rates at the top
plt.grid(axis='x')  # Add a grid for the x-axis

# Annotate the bar chart with the RATE values
for i, rate in enumerate(obesity_cancer_df['RATE']):
    plt.text(rate, i, f' {rate:.1f}', va='center', fontsize=10)

plt.show()

# %%
rate = obesity_cancer_df['RATE'].astype(float)
prevalence = obesity_cancer_df['Prevalence'].astype(float)

plt.figure(figsize=(10, 6))
plt.scatter(prevalence, rate, c='b', alpha=0.5)
plt.title('Cancer Rate vs. Obesity Prevalence')
plt.xlabel('Prevalence (%)')
plt.ylabel('Cancer Rate')
plt.grid(True)

# Annotate the data points with state names
for i, state in enumerate(obesity_cancer_df['STATE']):
    plt.annotate(state, (prevalence.iloc[i], rate.iloc[i]), fontsize=8, alpha=0.7)

plt.show()

# %%
import hvplot.pandas

map_plot_1 = obesity_cancer_df.hvplot.points(
    x='STATE',
    y='Prevalence',
    size='Prevalence',
    geo=True,
    tiles="OSM",
    frame_width=800,
    frame_height=600,
    color="STATE"
)

# Display the map plot
map_plot_1
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# //anaconda3/envs/myenv/lib/python3.8/site-packages/geoviews/operation/__init__.py:14: HoloviewsDeprecationWarning: 'ResamplingOperation' is deprecated and will be removed in version 1.18, use 'ResampleOperation2D' instead.
#   from holoviews.operation.datashader import (
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/IPython/core/formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/core/dimension.py:1287, in Dimensioned._repr_mimebundle_(self, include, exclude)
#    1280 def _repr_mimebundle_(self, include=None, exclude=None):
#    1281     """
#    1282     Resolves the class hierarchy for the class rendering the
#    1283     object using any display hooks registered on Store.display
#    1284     hooks.  The output of all registered display_hooks is then
#    1285     combined and returned.
#    1286     """
# -> 1287     return Store.render(self)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/core/options.py:1423, in Store.render(cls, obj)
#    1421 data, metadata = {}, {}
#    1422 for hook in hooks:
# -> 1423     ret = hook(obj)
#    1424     if ret is None:
#    1425         continue
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/ipython/display_hooks.py:280, in pprint_display(obj)
#     278 if not ip.display_formatter.formatters['text/plain'].pprint:
#     279     return None
# --> 280 return display(obj, raw_output=True)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/ipython/display_hooks.py:248, in display(obj, raw_output, **kwargs)
#     246 elif isinstance(obj, (CompositeOverlay, ViewableElement)):
#     247     with option_state(obj):
# --> 248         output = element_display(obj)
#     249 elif isinstance(obj, (Layout, NdLayout, AdjointLayout)):
#     250     with option_state(obj):
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/ipython/display_hooks.py:142, in display_hook.<locals>.wrapped(element)
#     140 try:
#     141     max_frames = OutputSettings.options['max_frames']
# --> 142     mimebundle = fn(element, max_frames=max_frames)
#     143     if mimebundle is None:
#     144         return {}, {}
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/ipython/display_hooks.py:188, in element_display(element, max_frames)
#     185 if type(element) not in Store.registry[backend]:
#     186     return None
# --> 188 return render(element)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/ipython/display_hooks.py:69, in render(obj, **kwargs)
#      66 if renderer.fig == 'pdf':
#      67     renderer = renderer.instance(fig='png')
# ---> 69 return renderer.components(obj, **kwargs)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/renderer.py:397, in Renderer.components(self, obj, fmt, comm, **kwargs)
#     394 embed = (not (dynamic or streams or self.widget_mode == 'live') or config.embed)
#     396 if embed or config.comms == 'default':
# --> 397     return self._render_panel(plot, embed, comm)
#     398 return self._render_ipywidget(plot)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/renderer.py:404, in Renderer._render_panel(self, plot, embed, comm)
#     402 doc = Document()
#     403 with config.set(embed=embed):
# --> 404     model = plot.layout._render_model(doc, comm)
#     405 if embed:
#     406     return render_model(model, comm)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/panel/viewable.py:509, in Renderable._render_model(self, doc, comm)
#     507 if comm is None:
#     508     comm = state._comm_manager.get_server_comm()
# --> 509 model = self.get_root(doc, comm)
#     511 if config.embed:
#     512     embed_state(self, model, doc,
#     513                 json=config.embed_json,
#     514                 json_prefix=config.embed_json_prefix,
#     515                 save_path=config.embed_save_path,
#     516                 load_path=config.embed_load_path,
#     517                 progress=False)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/panel/viewable.py:560, in Renderable.get_root(self, doc, comm, preprocess)
#     543 """
#     544 Returns the root model and applies pre-processing hooks
#     545
#    (...)
#     557 Returns the bokeh model corresponding to this panel object
#     558 """
#     559 doc = init_doc(doc)
# --> 560 root = self._get_model(doc, comm=comm)
#     561 if preprocess:
#     562     self._preprocess(root)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/panel/layout/base.py:146, in Panel._get_model(self, doc, root, parent, comm)
#     144 if root is None:
#     145     root = model
# --> 146 objects = self._get_objects(model, [], doc, root, comm)
#     147 props = dict(self._init_params(), objects=objects)
#     148 model.update(**self._process_param_change(props))
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/panel/layout/base.py:131, in Panel._get_objects(self, model, old_objects, doc, root, comm)
#     129 else:
#     130     try:
# --> 131         child = pane._get_model(doc, root, model, comm)
#     132     except RerenderError:
#     133         return self._get_objects(model, current_objects[:i], doc, root, comm)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/panel/pane/holoviews.py:367, in HoloViews._get_model(self, doc, root, parent, comm)
#     365     plot = self.object
#     366 else:
# --> 367     plot = self._render(doc, comm, root)
#     369 plot.pane = self
#     370 backend = plot.renderer.backend
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/panel/pane/holoviews.py:442, in HoloViews._render(self, doc, comm, root)
#     439     if comm:
#     440         kwargs['comm'] = comm
# --> 442 return renderer.get_plot(self.object, **kwargs)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/bokeh/renderer.py:70, in BokehRenderer.get_plot(self_or_cls, obj, doc, renderer, **kwargs)
#      63 @bothmethod
#      64 def get_plot(self_or_cls, obj, doc=None, renderer=None, **kwargs):
#      65     """
#      66     Given a HoloViews Viewable return a corresponding plot instance.
#      67     Allows supplying a document attach the plot to, useful when
#      68     combining the bokeh model with another plot.
#      69     """
# ---> 70     plot = super().get_plot(obj, doc, renderer, **kwargs)
#      71     if plot.document is None:
#      72         plot.document = Document() if self_or_cls.notebook_context else curdoc()
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/renderer.py:241, in Renderer.get_plot(self_or_cls, obj, doc, renderer, comm, **kwargs)
#     238     defaults = [kd.default for kd in plot.dimensions]
#     239     init_key = tuple(v if d is None else d for v, d in
#     240                      zip(plot.keys[0], defaults))
# --> 241     plot.update(init_key)
#     242 else:
#     243     plot = obj
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/plot.py:943, in DimensionedPlot.update(self, key)
#     941 def update(self, key):
#     942     if len(self) == 1 and key in (0, self.keys[0]) and not self.drawn:
# --> 943         return self.initialize_plot()
#     944     item = self.__getitem__(key)
#     945     self.traverse(lambda x: setattr(x, '_updated', True))
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/geoviews/plotting/bokeh/plot.py:107, in GeoPlot.initialize_plot(self, ranges, plot, plots, source)
#     105 def initialize_plot(self, ranges=None, plot=None, plots=None, source=None):
#     106     opts = {} if isinstance(self, HvOverlayPlot) else {'source': source}
# --> 107     fig = super(GeoPlot, self).initialize_plot(ranges, plot, plots, **opts)
#     108     if self.geographic and self.show_bounds and not self.overlaid:
#     109         from . import GeoShapePlot
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/bokeh/element.py:2760, in OverlayPlot.initialize_plot(self, ranges, plot, plots)
#    2758 self.tabs = self.tabs or any(isinstance(sp, TablePlot) for sp in self.subplots.values())
#    2759 if plot is None and not self.tabs and not self.batched:
# -> 2760     plot = self._init_plot(key, element, ranges=ranges, plots=plots)
#    2761     self._populate_axis_handles(plot)
#    2762 self.handles['plot'] = plot
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/bokeh/element.py:565, in ElementPlot._init_plot(self, key, element, plots, ranges)
#     562 subplots = list(self.subplots.values()) if self.subplots else []
#     564 axis_specs = {'x': {}, 'y': {}}
# --> 565 axis_specs['x']['x'] = self._axis_props(plots, subplots, element, ranges, pos=0) + (self.xaxis, {})
#     566 if self.multi_y:
#     567     if not bokeh32:
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/bokeh/element.py:424, in ElementPlot._axis_props(self, plots, subplots, element, ranges, pos, dim, range_tags_extras, extra_range_name)
#     422 else:
#     423     if isinstance(self, OverlayPlot):
# --> 424         l, b, r, t = self.get_extents(range_el, ranges, dim)
#     425     else:
#     426         l, b, r, t = self.get_extents(range_el, ranges)
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/geoviews/plotting/plot.py:67, in ProjectionPlot.get_extents(self, element, ranges, range_type)
#      65     (x0, x1), (y0, y1) = proj.x_limits, proj.y_limits
#      66     return (x0, y0, x1, y1)
# ---> 67 extents = super(ProjectionPlot, self).get_extents(element, ranges, range_type)
#      68 if not getattr(element, 'crs', None) or not self.geographic:
#      69     return extents
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/plot.py:1970, in GenericOverlayPlot.get_extents(self, overlay, ranges, range_type, dimension, **kwargs)
#    1969 def get_extents(self, overlay, ranges, range_type='combined', dimension=None, **kwargs):
# -> 1970     subplot_extents = self._get_subplot_extents(overlay, ranges, range_type, dimension)
#    1971     zrange = isinstance(self.projection, str) and self.projection == '3d'
#    1972     extents = {k: util.max_extents(rs, zrange) for k, rs in subplot_extents.items()}
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/holoviews/plotting/plot.py:1965, in GenericOverlayPlot._get_subplot_extents(self, overlay, ranges, range_type, dimension)
#    1963         sp_ranges = util.match_spec(layer, ranges) if ranges else {}
#    1964     for rt in extents:
# -> 1965         extent = subplot.get_extents(layer, sp_ranges, range_type=rt)
#    1966         extents[rt].append(extent)
#    1967 return extents
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/geoviews/plotting/plot.py:70, in ProjectionPlot.get_extents(self, element, ranges, range_type)
#      68 if not getattr(element, 'crs', None) or not self.geographic:
#      69     return extents
# ---> 70 elif any(e is None or not np.isfinite(e) for e in extents):
#      71     extents = None
#      72 else:
#
# File //anaconda3/envs/myenv/lib/python3.8/site-packages/geoviews/plotting/plot.py:70, in <genexpr>(.0)
#      68 if not getattr(element, 'crs', None) or not self.geographic:
#      69     return extents
# ---> 70 elif any(e is None or not np.isfinite(e) for e in extents):
#      71     extents = None
#      72 else:
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [STATE,Prevalence]
